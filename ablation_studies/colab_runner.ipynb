# %% [markdown]
# # Neuromorphic Decision Transformer - Ablation Studies Runner
#
# This notebook runs the targeted ablation studies for the Neuromorphic Decision Transformer project.

# %%
# Check GPU availability
# !nvidia-smi

# %%
# Clone the repository
# !git clone https://github.com/Vishal-sys-code/neuromorphic_decision_transformer.git
# %cd neuromorphic_decision_transformer

# %%
# Install dependencies
# !pip install gymnasium[classic_control] pyyaml tqdm torch numpy

# %%
# Run the ablation studies script
# !python ablation_studies/scripts/run_ablations.py
